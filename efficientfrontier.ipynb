# %%
import quandl
quandl.ApiConfig.api_key = "CXJRhqCt_s4YnjCDfYq4"
import numpy as np
import pandas as pd

# %%
pivoted = pd.read_csv("equity/data.csv", index_col="date")
pivoted=pivoted.iloc[::-1]
pivoted.head()
# Out:
#                   coalindia  ibulhsgfin   wipro   ltfh      tcs  sunpharma  \
# date
# 1-September-2015     355.40      726.15  562.85  62.70  2538.80     900.75
# 2-September-2015     344.50      707.25  555.90  62.55  2593.20     890.35
# 3-September-2015     345.65      709.90  566.70  63.50  2605.25     885.35
# 4-September-2015     346.75      721.10  553.70  63.05  2549.45     858.55
# 7-September-2015     337.60      724.25  551.90  62.25  2539.50     836.45
#
#                   biocon     pvr  axisbank  hdfcbank  tatamotors   cipla  \
# date
# 1-September-2015  436.90  815.05    480.15   1000.60      329.60  663.25
# 2-September-2015  437.70  807.45    466.85    995.65      325.35  650.05
# 3-September-2015  439.35  835.35    486.40   1010.45      333.35  656.85
# 4-September-2015  427.30  816.25    468.85    995.70      322.85  649.40
# 7-September-2015  427.35  783.40    450.55    984.60      323.60  649.30
#
#                      itc  spicejet  reliance     infy    bhel   dabur     sbi  \
# date
# 1-September-2015  315.55     24.25    840.15  1089.65  217.65  271.10  239.10
# 2-September-2015  320.00     24.20    849.30  1100.30  206.55  279.10  230.60
# 3-September-2015  320.05     24.35    853.75  1100.65  211.55  285.10  232.60
# 4-September-2015  316.45     23.00    835.60  1073.80  206.65  285.15  225.05
# 7-September-2015  313.25     22.50    833.05  1059.60  200.95  276.90  221.70
#
#                   bajfinance
# date
# 1-September-2015     4940.85
# 2-September-2015     5028.35
# 3-September-2015     5205.50
# 4-September-2015     5068.75
# 7-September-2015     5025.55

# %%
cov_matrix = pivoted.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
#             coalindia  ibulhsgfin     wipro      ltfh       tcs  sunpharma  \
# coalindia    0.000330    0.000206  0.000064  0.000155  0.000034   0.000074
# ibulhsgfin   0.000206    0.001642  0.000084  0.000556  0.000050   0.000143
# wipro        0.000064    0.000084  0.000700  0.000066  0.000112   0.000045
# ltfh         0.000155    0.000556  0.000066  0.000715  0.000093   0.000153
# tcs          0.000034    0.000050  0.000112  0.000093  0.000652   0.000059
# sunpharma    0.000074    0.000143  0.000045  0.000153  0.000059   0.000428
# biocon       0.000068    0.000171  0.000035  0.000157  0.000065   0.000116
# pvr          0.000085    0.000192  0.000047  0.000216  0.000042   0.000064
# axisbank     0.000122    0.000318  0.000091  0.000341  0.000085   0.000111
# hdfcbank     0.000056    0.000199  0.000058  0.000199  0.000049   0.000068
# tatamotors   0.000157    0.000383  0.000106  0.000336  0.000106   0.000132
# cipla        0.000066    0.000121  0.000046  0.000110  0.000035   0.000152
# itc          0.000069    0.000077  0.000051  0.000119  0.000057   0.000063
# spicejet     0.000116    0.000335  0.000047  0.000296  0.000049   0.000096
# itc         0.000406  0.000081  0.000085  0.000058  0.000109  0.000080
# spicejet    0.000081  0.001097  0.000109  0.000063  0.000231  0.000071
# reliance    0.000085  0.000109  0.000756  0.000081  0.000153  0.000083
# infy        0.000058  0.000063  0.000081  0.000678  0.000095  0.000081
# bhel        0.000109  0.000231  0.000153  0.000095  0.000858  0.000097
# dabur       0.000080  0.000071  0.000083  0.000081  0.000097  0.000241
# sbi         0.000119  0.000188  0.000155  0.000104  0.000284  0.000100
# bajfinance  0.000079  0.000228  0.000119  0.000139  0.000281  0.000118
#
#                  sbi  bajfinance
# coalindia   0.000128    0.000106
# ibulhsgfin  0.000329    0.000369
# wipro       0.000068    0.000110
# ltfh        0.000305    0.000402
# tcs         0.000059    0.000185
# sunpharma   0.000114    0.000046
# biocon      0.000122    0.000135
# pvr         0.000170    0.000217
# axisbank    0.000319    0.000284
# hdfcbank    0.000153    0.000197
# tatamotors  0.000278    0.000265
# cipla       0.000103    0.000041
# itc         0.000119    0.000079
# spicejet    0.000188    0.000228
# reliance    0.000155    0.000119
# infy        0.000104    0.000139
# bhel        0.000284    0.000281
# dabur       0.000100    0.000118
# sbi         0.000538    0.000234
# bajfinance  0.000234    0.004904

# %%
e_r = pivoted.pct_change().mean()
e_r
# Out:
# coalindia    -0.000629
# ibulhsgfin   -0.000216
# wipro        -0.000283
# ltfh          0.000401
# tcs           0.000187
# sunpharma    -0.000228
# biocon        0.000691
# pvr           0.000724
# axisbank      0.000299
# hdfcbank      0.000354
# tatamotors   -0.000267
# cipla         0.000229
# itc          -0.000214
# spicejet      0.001149
# reliance      0.001077
# infy          0.000162
# bhel         -0.000979
# dabur         0.000598
# sbi           0.000196
# bajfinance    0.001211
# dtype: float64

# %%
sd = pivoted.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
sd
# Out:
# coalindia     0.287405
# ibulhsgfin    0.640652
# wipro         0.418297
# ltfh          0.422656
# tcs           0.403683
# sunpharma     0.326948
# biocon        0.681738
# pvr           0.375541
# axisbank      0.382700
# hdfcbank      0.384236
# tatamotors    0.450275
# cipla         0.267293
# itc           0.318587
# spicejet      0.523645
# reliance      0.434637
# infy          0.411745
# bhel          0.463252
# dabur         0.245471
# sbi           0.366814
# bajfinance    1.107212
# dtype: float64

# %%
assets = pd.concat([e_r, sd], axis=1)
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#              Returns  Volatility
# coalindia  -0.000629    0.287405
# ibulhsgfin -0.000216    0.640652
# wipro      -0.000283    0.418297
# ltfh        0.000401    0.422656
# tcs         0.000187    0.403683
# sunpharma  -0.000228    0.326948
# biocon      0.000691    0.681738
# pvr         0.000724    0.375541
# axisbank    0.000299    0.382700
# hdfcbank    0.000354    0.384236
# tatamotors -0.000267    0.450275
# cipla       0.000229    0.267293
# itc        -0.000214    0.318587
# spicejet    0.001149    0.523645
# reliance    0.001077    0.434637
# infy        0.000162    0.411745
# bhel       -0.000979    0.463252
# dabur       0.000598    0.245471
# sbi         0.000196    0.366814
# bajfinance  0.001211    1.107212

# %%
p_ret = []
p_vol = []
p_weights = []

num_assets = len(pivoted.columns)
num_portfolios = 1000

# %%
for portfolio in range(num_portfolios):
    #weights = [.25, .75]
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, e_r)
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    sd = np.sqrt(var)
    ann_sd = sd*np.sqrt(250)
    p_vol.append(ann_sd)
weights
# Out:
# array([0.07334521, 0.04612334, 0.07188952, 0.0269685 , 0.06889269,
#        0.02313582, 0.02830544, 0.09885945, 0.04628912, 0.03330986,
#        0.10551452, 0.10620518, 0.03489981, 0.00460221, 0.02620695,
#        0.02733815, 0.05928931, 0.05762104, 0.05259802, 0.00860588])

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

# %%
for counter, symbol in enumerate(pivoted.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(data)
portfolios.head()
# Out:
#     Returns  Volatility  coalindia weight  ibulhsgfin weight  wipro weight  \
# 0  0.000190    0.192457          0.085322           0.020212      0.049093
# 1  0.000096    0.208099          0.092539           0.075717      0.071210
# 2  0.000269    0.196295          0.062907           0.034462      0.009834
# 3  0.000242    0.205917          0.081844           0.049742      0.063991
# 4  0.000140    0.238401          0.030598           0.039118      0.074458
#
#    ltfh weight  tcs weight  sunpharma weight  biocon weight  pvr weight  ...  \
# 0     0.041467    0.061198          0.013759       0.041901    0.066457  ...
# 1     0.085874    0.091017          0.034786       0.008096    0.065119  ...
# 2     0.062732    0.083069          0.005920       0.035091    0.020391  ...
# 3     0.069349    0.049474          0.029557       0.047089    0.085191  ...
# 4     0.070318    0.014137          0.016223       0.035344    0.108232  ...
#
#    tatamotors weight  cipla weight  itc weight  spicejet weight  \
# 0           0.051438      0.070291    0.063497         0.075236
# 1           0.051876      0.050993    0.013035         0.019902
# 2           0.018979      0.097523    0.029606         0.020134
# 3           0.012169      0.008643    0.061550         0.057846
# 4           0.100828      0.001910    0.088137         0.051216
#
#    reliance weight  infy weight  bhel weight  dabur weight  sbi weight  \
# 0         0.033163     0.074663     0.057277      0.070655    0.043584
# 1         0.015719     0.038090     0.049380      0.046831    0.026531
# 2         0.102544     0.081780     0.037414      0.060095    0.057301
# 3         0.027680     0.037902     0.015845      0.032681    0.080876
# 4         0.007157     0.018219     0.110745      0.036494    0.040359
#
#    bajfinance weight
# 0           0.018556
# 1           0.018063
# 2           0.014381
# 3           0.031599
# 4           0.072118
#
# [5 rows x 22 columns]

# %%
portfolios.plot.scatter(x='Volatility', y='Returns', grid=True)
